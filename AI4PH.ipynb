# %% [markdown]
# # COVID-19 VACCINE DATA IN ONTARIO, CANADA

# %% [markdown]
# # COVID-19 VACCINE DATA IN ONTARIO, CANADA

# %% [markdown]
# **pandas is used for data manipulation**

# %%
import pandas as pd 
filename = 'Ontario Vacc19.csv'
Vaccine_Doses = pd.read_csv(filename)

# %% [markdown]
# **.head(5)** visualizes the first five rows of the dataset

# %%
Vaccine_Doses.head(5)
# Out:
#    _id                 Date  PHU ID           PHU name  Agegroup  \
# 0    1  2021-07-26T00:00:00    2226    ALGOMA DISTRICT  12-17yrs
# 1    2  2021-07-26T00:00:00    2227       BRANT COUNTY  12-17yrs
# 2    3  2021-07-26T00:00:00    2230      DURHAM REGION  12-17yrs
# 3    4  2021-07-26T00:00:00    2233         GREY BRUCE  12-17yrs
# 4    5  2021-07-26T00:00:00    2234  HALDIMAND-NORFOLK  12-17yrs
#
#    At least one dose_cumulative  Second_dose_cumulative  \
# 0                          1830                     855
# 1                          2842                    1565
# 2                         16012                    7553
# 3                          2740                    1711
# 4                          1482                     772
#
#    fully_vaccinated_cumulative  third_dose_cumulative  Total population  \
# 0                            0                      0              6672
# 1                            0                      0             11221
# ...

# %% [markdown]
# **.tail(10)** visualizes the last ten rows of the dataset

# %%
Vaccine_Doses.tail(10)
# Out:
#            _id                 Date  PHU ID                    PHU name  \
# 537030  537031  2024-11-06T00:00:00    2262        THUNDER BAY DISTRICT
# 537031  537032  2024-11-06T00:00:00    2263                 TIMISKAMING
# 537032  537033  2024-11-06T00:00:00    2265             WATERLOO REGION
# 537033  537034  2024-11-06T00:00:00    2266  WELLINGTON-DUFFERIN-GUELPH
# 537034  537035  2024-11-06T00:00:00    2268        WINDSOR-ESSEX COUNTY
# 537035  537036  2024-11-06T00:00:00    2270                 YORK REGION
# 537036  537037  2024-11-06T00:00:00    3895                     TORONTO
# 537037  537038  2024-11-06T00:00:00    4913                SOUTHWESTERN
# 537038  537039  2024-11-06T00:00:00    5183                 HURON PERTH
# 537039  537040  2024-11-06T00:00:00    9999                     UNKNOWN
#
#                       Agegroup  At least one dose_cumulative  \
# 537030  Undisclosed_or_missing                            17
# ...

# %% [markdown]
# **Len()** returns the number of rows of the dataset

# %%
len(Vaccine_Doses)
# Out:
# 537040

# %% [markdown]
# **.info()** gives a brief overview of the dataset, which includes the count of both null and non-null, types of data and number of columns.

# %%
Vaccine_Doses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537040 entries, 0 to 537039
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   _id                           537040 non-null  int64
#  1   Date                          537040 non-null  object
#  2   PHU ID                        537040 non-null  int64
#  3   PHU name                      537040 non-null  object
#  4   Agegroup                      537040 non-null  object
#  5   At least one dose_cumulative  537040 non-null  int64
#  6   Second_dose_cumulative        537040 non-null  int64
#  7   fully_vaccinated_cumulative   537040 non-null  int64
#  8   third_dose_cumulative         537040 non-null  int64
#  9   Total population              537040 non-null  int64
#  10  Percent_at_least_one_dose     537040 non-null  float64
#  11  Percent_fully_vaccinated      537040 non-null  float64
# ...

# %% [markdown]
# **.describe()** shows the summary statistics for the numerical columns in a dataset

# %%
Vaccine_Doses.describe()
# Out:
#                 _id         PHU ID  At least one dose_cumulative  \
# count  537040.00000  537040.000000                  5.370400e+05
# mean   268520.50000    2676.657143                  1.056459e+05
# std    155030.23862    1435.080984                  2.620900e+05
# min         1.00000    2226.000000                  0.000000e+00
# 25%    134260.75000    2238.000000                  1.034000e+04
# 50%    268520.50000    2251.000000                  2.301200e+04
# 75%    402780.25000    2263.000000                  8.930725e+04
# max    537040.00000    9999.000000                  2.618858e+06
#
#        Second_dose_cumulative  fully_vaccinated_cumulative  \
# count            5.370400e+05                 5.370400e+05
# mean             7.479331e+03                 9.440551e+04
# std              6.670522e+04                 2.470852e+05
# min              0.000000e+00                 0.000000e+00
# 25%              0.000000e+00                 4.846000e+03
# ...

# %% [markdown]
# **.isnull()** checks for null or missing values while **.sum()** gives the sum isnull values

# %%
print(Vaccine_Doses.isnull().sum())
# Out:
# _id                             0
# Date                            0
# PHU ID                          0
# PHU name                        0
# Agegroup                        0
# At least one dose_cumulative    0
# Second_dose_cumulative          0
# fully_vaccinated_cumulative     0
# third_dose_cumulative           0
# Total population                0
# Percent_at_least_one_dose       0
# Percent_fully_vaccinated        0
# Percent_3doses                  0
# dtype: int64

# %% [markdown]
# Although the result above showed that there is no null value in the dataset but under the Agegroup we have "Undisclosed_or_missing" as values so we had to drop those rows using the code below. Also, I wanted to visualize the last 10 rows because it was at the end of the datasets that I noticed the invalid values. Hence, I wanted to visualize it to be sure my code worked.

# %%
Vaccine_Doses = Vaccine_Doses[Vaccine_Doses["Agegroup"] != "Undisclosed_or_missing"]
Vaccine_Doses.tail(10)
# Out:
#            _id                 Date  PHU ID                    PHU name  \
# 536995  536996  2024-11-06T00:00:00    2262        THUNDER BAY DISTRICT
# 536996  536997  2024-11-06T00:00:00    2263                 TIMISKAMING
# 536997  536998  2024-11-06T00:00:00    2265             WATERLOO REGION
# 536998  536999  2024-11-06T00:00:00    2266  WELLINGTON-DUFFERIN-GUELPH
# 536999  537000  2024-11-06T00:00:00    2268        WINDSOR-ESSEX COUNTY
# 537000  537001  2024-11-06T00:00:00    2270                 YORK REGION
# 537001  537002  2024-11-06T00:00:00    3895                     TORONTO
# 537002  537003  2024-11-06T00:00:00    4913                SOUTHWESTERN
# 537003  537004  2024-11-06T00:00:00    5183                 HURON PERTH
# 537004  537005  2024-11-06T00:00:00    9999                     UNKNOWN
#
#              Agegroup  At least one dose_cumulative  Second_dose_cumulative  \
# 536995  Ontario_5plus                        130964                       0
# ...

# %% [markdown]
# Additionally, I noticed that under the Total population had 0 but they had people who had received the vaccines which shows that ) as a value was incorrect and can be dropped

# %%
Vaccine_Doses = Vaccine_Doses[Vaccine_Doses["Total population"] != 0] 
Vaccine_Doses.tail(10)
# Out:
#            _id                 Date  PHU ID                    PHU name  \
# 536994  536995  2024-11-06T00:00:00    2261        SUDBURY AND DISTRICT
# 536995  536996  2024-11-06T00:00:00    2262        THUNDER BAY DISTRICT
# 536996  536997  2024-11-06T00:00:00    2263                 TIMISKAMING
# 536997  536998  2024-11-06T00:00:00    2265             WATERLOO REGION
# 536998  536999  2024-11-06T00:00:00    2266  WELLINGTON-DUFFERIN-GUELPH
# 536999  537000  2024-11-06T00:00:00    2268        WINDSOR-ESSEX COUNTY
# 537000  537001  2024-11-06T00:00:00    2270                 YORK REGION
# 537001  537002  2024-11-06T00:00:00    3895                     TORONTO
# 537002  537003  2024-11-06T00:00:00    4913                SOUTHWESTERN
# 537003  537004  2024-11-06T00:00:00    5183                 HURON PERTH
#
#              Agegroup  At least one dose_cumulative  Second_dose_cumulative  \
# 536994  Ontario_5plus                        170102                       0
# ...

# %% [markdown]
# Wanted to check how many rows have dropped after the cleaning so far and we had about 11 rows which were dropped

# %%
Vaccine_Doses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480896 entries, 0 to 537003
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   _id                           480896 non-null  int64
#  1   Date                          480896 non-null  object
#  2   PHU ID                        480896 non-null  int64
#  3   PHU name                      480896 non-null  object
#  4   Agegroup                      480896 non-null  object
#  5   At least one dose_cumulative  480896 non-null  int64
#  6   Second_dose_cumulative        480896 non-null  int64
#  7   fully_vaccinated_cumulative   480896 non-null  int64
#  8   third_dose_cumulative         480896 non-null  int64
#  9   Total population              480896 non-null  int64
#  10  Percent_at_least_one_dose     480896 non-null  float64
#  11  Percent_fully_vaccinated      480896 non-null  float64
# ...

# %% [markdown]
# pd.to_datetime() was used to convert the date to date time format

# %%
Vaccine_Doses["Date"] = pd.to_datetime(Vaccine_Doses["Date"])
Vaccine_Doses.head()
# Out:
#    _id       Date  PHU ID           PHU name  Agegroup  \
# 0    1 2021-07-26    2226    ALGOMA DISTRICT  12-17yrs
# 1    2 2021-07-26    2227       BRANT COUNTY  12-17yrs
# 2    3 2021-07-26    2230      DURHAM REGION  12-17yrs
# 3    4 2021-07-26    2233         GREY BRUCE  12-17yrs
# 4    5 2021-07-26    2234  HALDIMAND-NORFOLK  12-17yrs
#
#    At least one dose_cumulative  Second_dose_cumulative  \
# 0                          1830                     855
# 1                          2842                    1565
# 2                         16012                    7553
# 3                          2740                    1711
# 4                          1482                     772
#
#    fully_vaccinated_cumulative  third_dose_cumulative  Total population  \
# 0                            0                      0              6672
# 1                            0                      0             11221
# 2                            0                      0             52309
# ...

# %% [markdown]
# Dropped PHU ID column since it was npot so relevant in the analysis that I wanted to do

# %%
Vaccine_Doses = Vaccine_Doses.drop(columns=['PHU ID'])
Vaccine_Doses.head()
# Out:
#    _id       Date           PHU name  Agegroup  At least one dose_cumulative  \
# 0    1 2021-07-26    ALGOMA DISTRICT  12-17yrs                          1830
# 1    2 2021-07-26       BRANT COUNTY  12-17yrs                          2842
# 2    3 2021-07-26      DURHAM REGION  12-17yrs                         16012
# 3    4 2021-07-26         GREY BRUCE  12-17yrs                          2740
# 4    5 2021-07-26  HALDIMAND-NORFOLK  12-17yrs                          1482
#
#    Second_dose_cumulative  fully_vaccinated_cumulative  third_dose_cumulative  \
# 0                     855                            0                      0
# 1                    1565                            0                      0
# 2                    7553                            0                      0
# 3                    1711                            0                      0
# 4                     772                            0                      0
#
# ...

# %%
Vaccine_Doses['Agegroup'].value_counts()
# Out:
# Agegroup
# 12-17yrs          40800
# 18-29yrs          40800
# 30-39yrs          40800
# 40-49yrs          40800
# 50-59yrs          40800
# 60-69yrs          40800
# 70-79yrs          40800
# 80+               40800
# Adults_18plus     40800
# Ontario_12plus    40800
# 05-11yrs          36448
# Ontario_5plus     36448
# Name: count, dtype: int64

# %%
Vaccine_Doses['Agegroup'].value_counts(normalize=True)
# Out:
# Agegroup
# 12-17yrs          0.084842
# 18-29yrs          0.084842
# 30-39yrs          0.084842
# 40-49yrs          0.084842
# 50-59yrs          0.084842
# 60-69yrs          0.084842
# 70-79yrs          0.084842
# 80+               0.084842
# Adults_18plus     0.084842
# Ontario_12plus    0.084842
# 05-11yrs          0.075792
# Ontario_5plus     0.075792
# Name: proportion, dtype: float64

# %%
Vaccine_Doses['Agegroup'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='Agegroup'>

# %%
Vaccine_Doses['At least one dose_cumulative', 'Second_dose_cumulative'].value_counts()

# %%
Vaccine_Doses['At least one dose_cumulative' , 'Second_dose_cumulative'].value_counts(normalize=True)

# %%
Vaccine_Doses['At least one dose_cumulative', 'Second_dose_cumulative'].value_counts(normalize=True).plot(kind='bar')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up figure
plt.figure(figsize=(15, 5))

# Columns to visualize
columns_to_plot = ["Percent_at_least_one_dose", "Percent_fully_vaccinated", "Percent_3doses"]
titles = ["At Least One Dose (%)", "Fully Vaccinated (%)", "Third Dose (%)"]

# Plot histograms
for i, col in enumerate(columns_to_plot, 1):
    plt.subplot(1, 3, i)
    sns.histplot(df_cleaned[col], bins=30, kde=True, color='blue')
    plt.title(f"Distribution of {titles[i-1]}")
    plt.xlabel("Percentage")
    plt.ylabel("Count")

plt.tight_layout()
plt.show()
